# %%
import numpy as np
import pandas as pd
import math

# %%
df = pd.read_table("./data/0.txt",delimiter='\t', header = None)
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# e:\python\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#               0                    1    2                 3     4        5   \
# 0    LKh7zAJ4nwo      TheReceptionist  653     Entertainment   424    13021
# 1    7D0Mf4Kn4Xk            periurban  583             Music   201     6508
# 2    n1cEq1C8oqQ          Pipistrello  525            Comedy   125     1687
# 3    OHkEzL4Unck             ichannel  638            Comedy   299     8043
# 4    -boOvAGNKUc        mrpitifulband  639             Music   287     7548
# 5    hFFH8DaOHQg      istothehalfabee  592             Music   286     1759
# 6    LzHjIj3fpR8       Xelanderthomas  686            Comedy   168     4545
# 7    SDNkMu8ZT68             w00dy911  630    People & Blogs   186    10181
# 8    PkGUU_ggO3k          theresident  704     Entertainment   262    11235
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 29 columns):
# 0     189 non-null object
# 1     189 non-null object
# 2     189 non-null int64
# 3     189 non-null object
# 4     189 non-null int64
# 5     189 non-null int64
# 6     189 non-null float64
# 7     189 non-null int64
# 8     189 non-null int64
# 9     187 non-null object
# 10    186 non-null object
# 11    185 non-null object
# 12    184 non-null object
# 13    183 non-null object
# 14    183 non-null object
# 15    182 non-null object
# 16    182 non-null object
# 17    182 non-null object
# 18    182 non-null object
# 19    182 non-null object
# 20    182 non-null object
# 21    182 non-null object
# 22    182 non-null object
# 23    182 non-null object
# 24    182 non-null object
# 25    182 non-null object
# 26    181 non-null object
# 27    180 non-null object
# 28    179 non-null object
# dtypes: float64(1), int64(5), object(23)
# memory usage: 42.9+ KB

# %%
# 前8列无缺失值
list = ("videoId","uploader", "age", "category", "length","views", "rate","Ratings","conments")
data = pd.DataFrame()
for (i,j) in zip(list, range(10)):
    data[i] = df[j]
data.head()
# Out:
#        videoId         uploader  age       category  length  views  rate  \
# 0  LKh7zAJ4nwo  TheReceptionist  653  Entertainment     424  13021  4.34
# 1  7D0Mf4Kn4Xk        periurban  583          Music     201   6508  4.19
# 2  n1cEq1C8oqQ      Pipistrello  525         Comedy     125   1687  4.01
# 3  OHkEzL4Unck         ichannel  638         Comedy     299   8043  4.40
# 4  -boOvAGNKUc    mrpitifulband  639          Music     287   7548  4.48
#
#    Ratings  conments
# 0     1305       744
# 1      687       312
# 2      363       141
# 3      518       371
# 4      606       386

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 9 columns):
# videoId     189 non-null object
# uploader    189 non-null object
# age         189 non-null int64
# category    189 non-null object
# length      189 non-null int64
# views       189 non-null int64
# rate        189 non-null float64
# Ratings     189 non-null int64
# conments    189 non-null int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 13.4+ KB

# %%
df[9].head()
# Out:
# 0    DjdA-5oKYFQ
# 1    e2k0h6tPvGc
# 2    eprHhmurMHg
# 3    eyUSTmEUQRg
# 4    fmUwUURgsX0
# Name: 9, dtype: object

# %%
#查看第9列缺失值位置
df[df[9].isnull().values == True][9]
# Out:
# 92     NaN
# 173    NaN
# Name: 9, dtype: object

# %%
df.head()
# Out:
#             0                1    2              3    4      5     6     7   \
# 0  LKh7zAJ4nwo  TheReceptionist  653  Entertainment  424  13021  4.34  1305
# 1  7D0Mf4Kn4Xk        periurban  583          Music  201   6508  4.19   687
# 2  n1cEq1C8oqQ      Pipistrello  525         Comedy  125   1687  4.01   363
# 3  OHkEzL4Unck         ichannel  638         Comedy  299   8043  4.40   518
# 4  -boOvAGNKUc    mrpitifulband  639          Music  287   7548  4.48   606
#
#     8            9   ...           19           20           21           22  \
# 0  744  DjdA-5oKYFQ  ...  vmdPOOd6cxI  KRHfMQqSHpk  pIMpORZthYw  1tUDzOp10pk
# 1  312  e2k0h6tPvGc  ...  EzKwOYLh-S0  eUIfRyrqwp8  AK8Wtfwe-1k  Eq4hGkIqBGw
# 2  141  eprHhmurMHg  ...  yLup8wjbSIo  lbf4d1pZI9c  uRQYan_-CTQ  gnpvEvuiFoQ
# 3  371  eyUSTmEUQRg  ...  LQUV_XGzHmA  8OmL_BJRLRw  qeCFW97-fOA  DVNwUKAuB3I
# 4  386  fmUwUURgsX0  ...  eV2SdBITv8k  cIO6nFDnNs4  Bd7nAtOEA3U  RZo5MisSTWo
#
# ...

# %%
lines = pd.DataFrame()
data["relatedId"] = ''

# %%
for row in df.itertuples():
    line = []
    for j in range(10,len(row)):
        if row[j] != "":
            line.append(row[j])
        else:
            line = []
            break
#     print(line)
    data["relatedId"][row[0]] = line
# Out:
# e:\python\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
data.head()
# Out:
#        videoId         uploader  age       category  length  views  rate  \
# 0  LKh7zAJ4nwo  TheReceptionist  653  Entertainment     424  13021  4.34
# 1  7D0Mf4Kn4Xk        periurban  583          Music     201   6508  4.19
# 2  n1cEq1C8oqQ      Pipistrello  525         Comedy     125   1687  4.01
# 3  OHkEzL4Unck         ichannel  638         Comedy     299   8043  4.40
# 4  -boOvAGNKUc    mrpitifulband  639          Music     287   7548  4.48
#
#    Ratings  conments                                          relatedId
# 0     1305       744  [DjdA-5oKYFQ, NxTDlnOuybo, c-8VuICzXtU, DH56yr...
# 1      687       312  [e2k0h6tPvGc, yuO6yjlvXe8, VqpnWBo-R4E, bdDskr...
# 2      363       141  [eprHhmurMHg, i30NkTJOrak, 2XtLgZol5wI, 3nH5Tc...
# 3      518       371  [eyUSTmEUQRg, FDIH1GNQXQE, Wtj31off8-I, mDjwzh...
# 4      606       386  [fmUwUURgsX0, bR27ACWomug, LlH7WcVptw8, saBmFp...

# %%
data.tail()
# Out:
#          videoId         uploader  age         category  length    views  \
# 184  bNF_P281Uu4  mattharding2718  490  Travel & Places     222  5231539
# 185  seGhTWE98DU        vidsquare  619            Music     198  3296342
# 186  N0TR0Irx4Y0         Brookers  228           Comedy     140  3836122
# 187  P1OXAQHv09E            smosh  434           Comedy      59  3068566
# 188  o4x-VW_rCSE      HollyW00d81  581    Entertainment      74  3534116
#
#      rate  Ratings  conments  \
# 184  4.81    29152     12529
# 185  4.57    13657      8639
# 186  3.16    12342      8066
# 187  4.55    15530      7919
# 188  4.48     9538      7756
#
#                                              relatedId
# 184  [7WmMcqp670s, RFtTSisZtVY, JFeSH655mas, 6FzTEV...
# 185  [xd03Xz7U41A, e5eLJIVY2zs, 5-uT93fl8aE, OIpslH...
# 186  [N0TR0Irx4Y0, hX21wbRAkx4, OnN9sX_Plvs, ygakq6...
# 187  [uGiGFQDS7mQ, j1aBQPCZoNE, WsmC6GXMj3I, pjgxSf...
# 188  [o4x-VW_rCSE, d2FEj5BCmmM, 8kOs3J0a2aI, 7ump9i...

# %%
data.relatedId[92] = []
# Out:
# e:\python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data.relatedId[173] = []
# Out:
# e:\python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 10 columns):
# videoId      189 non-null object
# uploader     189 non-null object
# age          189 non-null int64
# category     189 non-null object
# length       189 non-null int64
# views        189 non-null int64
# rate         189 non-null float64
# Ratings      189 non-null int64
# conments     189 non-null int64
# relatedId    189 non-null object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 14.8+ KB
